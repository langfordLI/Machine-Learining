# %% [markdown]
# # foundation plot

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(10, 4), index = pd.date_range('2018/12/18', periods = 10), columns = list('ABCD'))
df.plot()

# %% [markdown]
# # The bar chart

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 4), columns = ['a', 'b', 'c', 'd'])
df.plot.bar()

# %% [markdown]
# # stacking bar chart

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(10, 4), columns = ['a', 'b', 'c', 'd'])
df.plot.bar(stacked = True)

# %% [markdown]
# # horizontal bar graph

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns = ['a', 'b', 'c', 'd'])
df.plot.barh(stacked = True)

# %% [markdown]
# # histogram

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 'c': np.random.randn(1000) - 1}, columns = ['a', 'b', 'c'])
df.plot.hist(bins = 20)

# %% [markdown]
# # different columns histogram

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000), 'c': np.random.randn(1000) - 1}, columns = ['a', 'b', 'c'])
df.hist(bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x037A62D0>,
# ...
#       dtype=object)

# %% [markdown]
# # Box Figure

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns = ['A', 'B', 'C', 'D', 'E'])
df.plot.box()

# %% [markdown]
# # Region Fast Shape

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns = ['a', 'b', 'c', 'd'])
df.plot.area()

# %% [markdown]
# # scatter figure

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns = ['a', 'b', 'c', 'd'])
df.plot.scatter(x = 'a', y = 'b')

# %% [markdown]
# # Pie Chart

# %%
df = pd.DataFrame(3 * np.random.rand(4), index = ['a', 'b', 'c', 'd'], columns = ['x']) # 3 express: expand 3 times
df.plot.pie(subplots = True)
# Out:
# [0.75658916 0.90218458 0.99686663 2.35715682]
# [0.36754345 0.82316644 0.93191871 0.01268901]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0DEEFA30>],
#       dtype=object)
